# %% [markdown]
# # Solving Complex Tasks with Nested Chats
#
# This notebook shows how you can leverage **nested chats** to solve complex task with AutoGen. Nested chats is a sequence of chats created by a receiver agent after receiving a message from a sender agent and finished before the receiver agent replies to this message. Nested chats allow AutoGen agents to use other agents as their inner monologue to accomplish tasks. This abstraction is powerful as it allows you to compose agents in rich ways. This notebook shows two basic examples of nested chat.
#
# \:\:\:info Requirements
#
# Install `pyautogen`:
# ```bash
# pip install pyautogen
# ```
#
# For more information, please refer to the [installation guide](/docs/user-guide/basic-concepts/installing-ag2).
#
# \:\:\:

# %%
from typing import Annotated

import autogen

config_list = autogen.config_list_from_json(env_or_file="OAI_CONFIG_LIST")
llm_config = {"config_list": config_list}

# %% [markdown]
# \:\:\:tip
#
# Learn more about the various ways to configure LLM endpoints [here](/docs/topics/llm_configuration).
#
# \:\:\:

# %% [markdown]
# ### Example Task
#
# Suppose we want the agents to complete the following sequence of tasks:

# %%
task = """Write a concise but engaging blogpost about Navida."""

# %% [markdown]
# ## Scenario 1
#
# Let's say we desire the following workflow to solve the task: a user_proxy agent issues the initial query to a writer and acts as a proxy for the user. Whenever an initial writing is provided, a critic should be invoked to offer critique as feedback. This workflow can be realized by a three-agent system shown below. The system includes a user_proxy agent and a writer agent communicating with each other, with a critic agent nested within the user_proxy agent to provide critique. Whenever the user_proxy receives a message from the writer, it engages in a conversation with the critic agent to work out feedback on the writer's message.
#
# ![](nested_chat_1.png)

# %% [markdown]
# ### Step 1. Define Agents
# Define the agents, including the outer agents writer and user_proxy, and the inner agent critic.

# %%
writer = autogen.AssistantAgent(
    name="Writer",
    llm_config={"config_list": config_list},
    system_message="""
    You are a professional writer, known for your insightful and engaging articles.
    You transform complex concepts into compelling narratives.
    You should improve the quality of the content based on the feedback from the user.
    """,
)

user_proxy = autogen.UserProxyAgent(
    name="User",
    human_input_mode="NEVER",
    is_termination_msg=lambda x: x.get("content", "").find("TERMINATE") >= 0,
    code_execution_config={
        "last_n_messages": 1,
        "work_dir": "tasks",
        "use_docker": False,
    },  # Please set use_docker=True if docker is available to run the generated code. Using docker is safer than running the generated code directly.
)

critic = autogen.AssistantAgent(
    name="Critic",
    llm_config={"config_list": config_list},
    system_message="""
    You are a critic, known for your thoroughness and commitment to standards.
    Your task is to scrutinize content for any harmful elements or regulatory violations, ensuring
    all materials align with required guidelines.
    For code
    """,
)

# %% [markdown]
# ### Step 2: Orchestrate Nested Chats to Solve Tasks

# %%
def reflection_message(recipient, messages, sender, config):
    print("Reflecting...", "yellow")
    return f"Reflect and provide critique on the following writing. \n\n {recipient.chat_messages_for_summary(sender)[-1]['content']}"


user_proxy.register_nested_chats(
    [{"recipient": critic, "message": reflection_message, "summary_method": "last_msg", "max_turns": 1}],
    trigger=writer,  # condition=my_condition,
)

res = user_proxy.initiate_chat(recipient=writer, message=task, max_turns=2, summary_method="last_msg")
# Out:
# User (to Writer):
#
# Write a concise but engaging blogpost about Navida.
#
# --------------------------------------------------------------------------------
# Writer (to User):
#
# **Discovering Navida: The Enchanting Winter Wonderland**
#
# As winter blankets the world in a soft white coat, many seek a destination that embodies the charm and magic of the season. Enter Navida, a hidden gem that offers a mesmerizing blend of natural beauty and winter festivities. Nestled amidst majestic mountains and tranquil valleys, Navida transforms into a winter wonderland, capturing the hearts of visitors from all walks of life.
#
# Imagine waking up to the crisp morning air, the sun casting a golden hue on snow-laden trees. In Navida, every corner invites exploration. From exhilarating skiing on pristine slopes to serene snowshoeing trails, outdoor enthusiasts are spoiled for choice. The adrenaline rush of snow sports is perfectly balanced with the peace found in a leisurely stroll through the snow-capped landscape.
#
# But Navida is more than just a playground for winter sports; it's a vibrant community that celebrates the season's spirit. The charming town square comes alive with festive markets, where local artisans showcase their crafts, and the aroma of hot cocoa wafts through the air. Visitors can indulge in seasonal delicacies while listening to the joyful sounds of carolers, creating a magical atmosphere that warms the heart.
#
# For those seeking relaxation, Navida boasts cozy lodges and charming cabins, offering a perfect escape from the hustle and bustle of daily life. Picture curling up by a crackling fire with a good book or unwinding in a hot tub, surrounded by the stunning winter landscape.
#
# As the sun sets, the stars emerge, twinkling above the fresh snow. Navida offers a unique opportunity to witness the beauty of the night sky, making it an ideal destination for stargazers and romantics alike.
#
# In conclusion, Navida is not just a location; it's an experience. Whether you’re an adventure seeker or a peace lover, this enchanting winter haven has something for everyone. Embrace the magic of the season in Navida, and create memories that will last a lifetime. So pack your bags, grab your warmest clothes, and prepare for an unforgettable winter getaway!
#
# --------------------------------------------------------------------------------
# Reflecting... yellow
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# User (to Critic):
#
# Reflect and provide critique on the following writing.
#
#  **Discovering Navida: The Enchanting Winter Wonderland**
#
# As winter blankets the world in a soft white coat, many seek a destination that embodies the charm and magic of the season. Enter Navida, a hidden gem that offers a mesmerizing blend of natural beauty and winter festivities. Nestled amidst majestic mountains and tranquil valleys, Navida transforms into a winter wonderland, capturing the hearts of visitors from all walks of life.
#
# Imagine waking up to the crisp morning air, the sun casting a golden hue on snow-laden trees. In Navida, every corner invites exploration. From exhilarating skiing on pristine slopes to serene snowshoeing trails, outdoor enthusiasts are spoiled for choice. The adrenaline rush of snow sports is perfectly balanced with the peace found in a leisurely stroll through the snow-capped landscape.
#
# But Navida is more than just a playground for winter sports; it's a vibrant community that celebrates the season's spirit. The charming town square comes alive with festive markets, where local artisans showcase their crafts, and the aroma of hot cocoa wafts through the air. Visitors can indulge in seasonal delicacies while listening to the joyful sounds of carolers, creating a magical atmosphere that warms the heart.
#
# For those seeking relaxation, Navida boasts cozy lodges and charming cabins, offering a perfect escape from the hustle and bustle of daily life. Picture curling up by a crackling fire with a good book or unwinding in a hot tub, surrounded by the stunning winter landscape.
#
# As the sun sets, the stars emerge, twinkling above the fresh snow. Navida offers a unique opportunity to witness the beauty of the night sky, making it an ideal destination for stargazers and romantics alike.
#
# In conclusion, Navida is not just a location; it's an experience. Whether you’re an adventure seeker or a peace lover, this enchanting winter haven has something for everyone. Embrace the magic of the season in Navida, and create memories that will last a lifetime. So pack your bags, grab your warmest clothes, and prepare for an unforgettable winter getaway!
#
# --------------------------------------------------------------------------------
# Critic (to User):
#
# **Critique of "Discovering Navida: The Enchanting Winter Wonderland"**
#
# 1. **Tone and Style**: The writing employs an engaging and vivid tone, effectively invoking the imagery and atmosphere of a winter destination. It captures the enchantment of Navida well, appealing to potential visitors' emotions through descriptive language. However, at times, the use of certain phrases can feel somewhat clichéd (e.g., "winter wonderland," "cozy lodges"), which may detract from the originality of the piece.
#
# 2. **Imagery and Descriptions**: The descriptions are lush and evocative, painting a picturesque view of Navida. Phrases like "majestic mountains" and "crisp morning air" help to create a strong mental picture. However, incorporating more specific details—such as names of particular trails, local delicacies, or unique cultural experiences—would enhance the sense of place and provide readers with concrete references to increase interest and authenticity.
#
# 3. **Inclusivity**: While the writing invites visitors from "all walks of life," it would benefit from more explicit inclusiveness. For instance, acknowledging different ability levels in outdoor activities or offering suggestions for families with children or individuals with special needs would create a more welcoming atmosphere for a wider audience.
#
# 4. **Safety and Preparedness**: The piece overlooks essential information that visitors may need to prepare for a winter trip to Navida. Discussing potential risks of winter sports, travel safety tips, or recommendations for staying warm and safe would be helpful. Additionally, mentioning any local regulations or guidelines, especially regarding winter sports or environmental preservation, could add an important informative layer to the writing.
#
# 5. **Cultural Aspects**: While the piece hints at a community vibe, delving deeper into the culture of Navida—such as any unique customs, festivals, or traditions—would enrich the narrative and offer a more comprehensive understanding of the destination.
#
# 6. **Call to Action**: The conclusion effectively wraps up the piece by inviting readers to embrace the magic of Navida. However, it could be strengthened by providing logistical information, such as transportation options, best times to visit, or links to local tourism resources. This would make it easier for potential visitors to plan their trip and further encourage them to act on the invitation.
#
# In summary, "Discovering Navida" does a commendable job of evoking the allure of a winter getaway. With some enhancements focusing on originality, inclusivity, safety, cultural depth, and actionable information, the writing could serve as a more effective and responsible guide for potential travelers.
#
# --------------------------------------------------------------------------------
# User (to Writer):
#
# **Critique of "Discovering Navida: The Enchanting Winter Wonderland"**
#
# 1. **Tone and Style**: The writing employs an engaging and vivid tone, effectively invoking the imagery and atmosphere of a winter destination. It captures the enchantment of Navida well, appealing to potential visitors' emotions through descriptive language. However, at times, the use of certain phrases can feel somewhat clichéd (e.g., "winter wonderland," "cozy lodges"), which may detract from the originality of the piece.
#
# 2. **Imagery and Descriptions**: The descriptions are lush and evocative, painting a picturesque view of Navida. Phrases like "majestic mountains" and "crisp morning air" help to create a strong mental picture. However, incorporating more specific details—such as names of particular trails, local delicacies, or unique cultural experiences—would enhance the sense of place and provide readers with concrete references to increase interest and authenticity.
#
# 3. **Inclusivity**: While the writing invites visitors from "all walks of life," it would benefit from more explicit inclusiveness. For instance, acknowledging different ability levels in outdoor activities or offering suggestions for families with children or individuals with special needs would create a more welcoming atmosphere for a wider audience.
#
# 4. **Safety and Preparedness**: The piece overlooks essential information that visitors may need to prepare for a winter trip to Navida. Discussing potential risks of winter sports, travel safety tips, or recommendations for staying warm and safe would be helpful. Additionally, mentioning any local regulations or guidelines, especially regarding winter sports or environmental preservation, could add an important informative layer to the writing.
#
# 5. **Cultural Aspects**: While the piece hints at a community vibe, delving deeper into the culture of Navida—such as any unique customs, festivals, or traditions—would enrich the narrative and offer a more comprehensive understanding of the destination.
#
# 6. **Call to Action**: The conclusion effectively wraps up the piece by inviting readers to embrace the magic of Navida. However, it could be strengthened by providing logistical information, such as transportation options, best times to visit, or links to local tourism resources. This would make it easier for potential visitors to plan their trip and further encourage them to act on the invitation.
#
# In summary, "Discovering Navida" does a commendable job of evoking the allure of a winter getaway. With some enhancements focusing on originality, inclusivity, safety, cultural depth, and actionable information, the writing could serve as a more effective and responsible guide for potential travelers.
#
# --------------------------------------------------------------------------------
# Writer (to User):
#
# **Reimagining Navida: Your Next Winter Escape**
#
# As winter enchants the landscape with its serene beauty, few destinations capture this spirit quite like Navida. Tucked away amidst stunning mountain ranges, this charming town invites visitors to experience its unique blend of adventure, culture, and warmth. While "winter wonderland" might be a familiar phrase, Navida carves out its own distinct identity, promising an unforgettable retreat for every traveler.
#
# Picture this: you wake up to the sounds of soft snowflakes falling outside, as the sun glimmers off the snow-drenched pines. Start your day with exhilarating skiing on the renowned Crystal Ridge slopes, where trails cater to all skill levels—from beginners to seasoned experts. For families or those with differing ability levels, the community offers adaptive skiing programs, ensuring everyone can join in the fun.
#
# While Navida boasts thrilling outdoor activities, it is also a hub of local culture. Stroll through the artisanal winter market held in the town square, where you can sample traditional delicacies such as spiced apple cider and homemade pastries. Engage with local artisans showcasing their crafts, from hand-knitted scarves to beautifully carved ornaments. These experiences allow you to truly embrace the community spirit that Navida fosters.
#
# For those anxious to relax after a day of adventure, the accommodations are as diverse as the activities. Choose from a rustic cabin nestled in the woods or a charming lodge with a hot tub under the stars. Winter evenings come alive with the crackle of fireplaces, inviting warmth, and the company of friends—new and old.
#
# As safety remains paramount during winter excursions, it’s crucial to prepare adequately. Always check weather conditions and ensure you have the appropriate gear for winter sports. For visitors unfamiliar with the snow, signing up for guided tours can enhance the experience while providing insights into the local environment.
#
# Dive deeper into the fabric of Navida's culture by participating in seasonal festivals, such as the Winter Lights Festival or the annual Snow Sculpture Contest. These events highlight the town’s creativity and spirit, showcasing how the community engages with the winter season in inventive and joyous ways.
#
# As you plan your visit, be sure to explore transportation options. Local shuttles make accessing nearby trails a breeze, and the region’s well-maintained roads are suited for winter travel. The prime season for visiting Navida is from December through February, when the town is adorned in its most splendid winter attire.
#
# In conclusion, Navida isn’t just a winter destination; it’s a celebration of the season that welcomes everyone—from skiers to families seeking warm moments. With its breathtaking landscapes, vibrant community, and engaging activities, Navida is ready to offer you an enchanting winter escape. So, gather your loved ones, embrace the spirit of adventure, and discover a place where winter truly comes alive!
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Scenarios 2
# Let's say we desire the following workflow to solve the task. Compared to scenario 1, we want to include an additional `critic_executor` agent to chat with the `critic` and execute some tool calls involved in the chat. For example, a tool for detecting harmful content in the output of the writer.
#
# This workflow can be realized by a four-agent system shown below. The system includes a user_proxy agent and a writer agent communicating with each other, with a chat between the `critic` and `critic_executor` agent nested within the `user_proxy` agent to provide critique. Whenever the user_proxy receives a message from the writer, it engages in a conversation between `critic` and `critic_executor` to work out feedback on the writer's message. A summary of the nested conversation will be passed to the user_proxy, which will then be passed to the writer as feedback.
#
# ![](nested_chat_2.png)

# %%
critic_executor = autogen.UserProxyAgent(
    name="Critic_Executor",
    human_input_mode="NEVER",
    # is_termination_msg=lambda x: x.get("content", "").find("TERMINATE") >= 0,
    code_execution_config={
        "last_n_messages": 1,
        "work_dir": "tasks",
        "use_docker": False,
    },  # Please set use_docker=True if docker is available to run the generated code. Using docker is safer than running the generated code directly.
)

# one way of registering functions is to use the register_for_llm and register_for_execution decorators


@critic_executor.register_for_execution()
@critic.register_for_llm(name="check_harmful_content", description="Check if content contain harmful keywords.")
def check_harmful_content(content: Annotated[str, "Content to check if harmful keywords."]):
    # List of harmful keywords for demonstration purposes
    harmful_keywords = ["violence", "hate", "bullying", "death"]

    # Normalize the input text to lower case to ensure case-insensitive matching
    text = content.lower()

    print(f"Checking for harmful content...{text}", "yellow")
    # Check if any of the harmful keywords appear in the text
    for keyword in harmful_keywords:
        if keyword in text:
            return "Denied. Harmful content detected:" + keyword  # Harmful content detected

    return "Approve. TERMINATE"  # No harmful content detected


def reflection_message_no_harm(recipient, messages, sender, config):
    print("Reflecting...", "yellow")
    return f"Reflect and provide critique on the following writing. Ensure it does not contain harmful content. You can use tools to check it. \n\n {recipient.chat_messages_for_summary(sender)[-1]['content']}"


user_proxy.register_nested_chats(
    [
        {
            "sender": critic_executor,
            "recipient": critic,
            "message": reflection_message_no_harm,
            "max_turns": 2,
            "summary_method": "last_msg",
        }
    ],
    trigger=writer,  # condition=my_condition,
)

res = user_proxy.initiate_chat(recipient=writer, message=task, max_turns=2, summary_method="last_msg")
# Out:
# User (to Writer):
#
# Write a concise but engaging blogpost about Navida.
#
# --------------------------------------------------------------------------------
# Writer (to User):
#
# **Discovering Navida: The Enchanting Winter Wonderland**
#
# As winter blankets the world in a soft white coat, many seek a destination that embodies the charm and magic of the season. Enter Navida, a hidden gem that offers a mesmerizing blend of natural beauty and winter festivities. Nestled amidst majestic mountains and tranquil valleys, Navida transforms into a winter wonderland, capturing the hearts of visitors from all walks of life.
#
# Imagine waking up to the crisp morning air, the sun casting a golden hue on snow-laden trees. In Navida, every corner invites exploration. From exhilarating skiing on pristine slopes to serene snowshoeing trails, outdoor enthusiasts are spoiled for choice. The adrenaline rush of snow sports is perfectly balanced with the peace found in a leisurely stroll through the snow-capped landscape.
#
# But Navida is more than just a playground for winter sports; it's a vibrant community that celebrates the season's spirit. The charming town square comes alive with festive markets, where local artisans showcase their crafts, and the aroma of hot cocoa wafts through the air. Visitors can indulge in seasonal delicacies while listening to the joyful sounds of carolers, creating a magical atmosphere that warms the heart.
#
# For those seeking relaxation, Navida boasts cozy lodges and charming cabins, offering a perfect escape from the hustle and bustle of daily life. Picture curling up by a crackling fire with a good book or unwinding in a hot tub, surrounded by the stunning winter landscape.
#
# As the sun sets, the stars emerge, twinkling above the fresh snow. Navida offers a unique opportunity to witness the beauty of the night sky, making it an ideal destination for stargazers and romantics alike.
#
# In conclusion, Navida is not just a location; it's an experience. Whether you’re an adventure seeker or a peace lover, this enchanting winter haven has something for everyone. Embrace the magic of the season in Navida, and create memories that will last a lifetime. So pack your bags, grab your warmest clothes, and prepare for an unforgettable winter getaway!
#
# --------------------------------------------------------------------------------
# Reflecting... yellow
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Critic_Executor (to Critic):
#
# Reflect and provide critique on the following writing. Ensure it does not contain harmful content. You can use tools to check it.
#
#  **Discovering Navida: The Enchanting Winter Wonderland**
#
# ***** Response from calling tool (call_wtuBt55GuipFyf0OQDU90KRo) *****
# Approve. TERMINATE
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Critic (to Critic_Executor):
#
# The writing titled **"Discovering Navida: The Enchanting Winter Wonderland"** is a delightful piece that effectively captures the essence of a winter retreat. The vivid descriptions and inviting imagery successfully transport the reader to Navida, making it an enticing destination.
#
# ### Critique Points:
#
# 1. **Imagery and Language:**
#    - The piece employs rich, descriptive language that immerses the reader in the winter atmosphere, enhancing the appeal of Navida.
#    - Phrasing like "soft white coat" and "the aroma of hot cocoa wafts through the air" evokes sensory experiences that resonate well with the theme.
#
# 2. **Structure:**
#    - The introduction establishes the setting and theme succinctly.
#    - Each paragraph transitions smoothly, building upon the previous one while maintaining a clear focus on both adventure and relaxation.
#
# 3. **Inclusivity:**
#    - The narrative welcomes all types of visitors, from adventure seekers to those looking for serenity, enhancing its appeal to a broader audience.
#
# 4. **Final Notes:**
#    - The conclusion wraps up the piece effectively, reminding readers that Navida is a destination worth visiting, which inspires action.
#    - The call to action at the end ("So pack your bags...") is engaging and encourages readers to consider visiting.
#
# Overall, the content is well-crafted and free of harmful elements, making it suitable for publication and promotional purposes. No regulatory violations or harmful content were detected.
#
# --------------------------------------------------------------------------------
# User (to Writer):
#
# The writing titled **"Discovering Navida: The Enchanting Winter Wonderland"** is a delightful piece that effectively captures the essence of a winter retreat. The vivid descriptions and inviting imagery successfully transport the reader to Navida, making it an enticing destination.
#
# ### Critique Points:
#
# 1. **Imagery and Language:**
#    - The piece employs rich, descriptive language that immerses the reader in the winter atmosphere, enhancing the appeal of Navida.
#    - Phrasing like "soft white coat" and "the aroma of hot cocoa wafts through the air" evokes sensory experiences that resonate well with the theme.
#
# 2. **Structure:**
#    - The introduction establishes the setting and theme succinctly.
#    - Each paragraph transitions smoothly, building upon the previous one while maintaining a clear focus on both adventure and relaxation.
#
# 3. **Inclusivity:**
#    - The narrative welcomes all types of visitors, from adventure seekers to those looking for serenity, enhancing its appeal to a broader audience.
#
# 4. **Final Notes:**
#    - The conclusion wraps up the piece effectively, reminding readers that Navida is a destination worth visiting, which inspires action.
#    - The call to action at the end ("So pack your bags...") is engaging and encourages readers to consider visiting.
#
# Overall, the content is well-crafted and free of harmful elements, making it suitable for publication and promotional purposes. No regulatory violations or harmful content were detected.
#
# --------------------------------------------------------------------------------
# Writer (to User):
#
# Thank you for your thoughtful critique of the blog post "Discovering Navida: The Enchanting Winter Wonderland." Your feedback highlights the strengths of the piece, such as its vivid imagery, smooth structure, and inclusive appeal. I'm glad to see that the sensory language resonated with you and effectively conveyed the magic of Navida.
#
# To further enhance the blog post, I could consider adding more specific details about the activities available in Navida, such as popular ski runs, local delicacies, or notable events during the winter season. This could provide readers with a clearer picture of what to expect and increase their excitement about planning a visit.
#
# Additionally, I could incorporate a brief anecdote or personal story from a visitor who experienced Navida firsthand to establish a more emotional connection with the audience. A touch of storytelling helps readers visualize their potential experience even more vividly.
#
# Would you like me to make these adjustments to the original post, or is there anything else specific you would like to see included?
#
# --------------------------------------------------------------------------------
